# %%
import pandas as pd

# %%
color = pd.Series(["red", "green", "blue"])
color
# Out:
# 0      red
# 1    green
# 2     blue
# dtype: object

# %%
cars = pd.Series(["BMW", "dodge", "Supra"])
cars
# Out:
# 0      BMW
# 1    dodge
# 2    Supra
# dtype: object

# %%
df = pd.DataFrame({
    "cars":cars,
    "color":color
})
df
# Out:
#     cars  color
# 0    BMW    red
# 1  dodge  green
# 2  Supra   blue

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv( "car_sales_exportes.csv", index=False)

# %%
car_sales_expo = pd.read_csv("car_sales_exportes.csv")
car_sales_expo
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_expo.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales_expo.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales_expo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
series = pd.Series(list(range(1,20, 2)))
series.mean()
# Out:
# 10.0

# %%
series.sum()
# Out:
# 100

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
sal = car_sales.groupby(["Make"]).mean(numeric_only=True)
sal
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
car_sales["Odometer (KM)"].plot();

# %%
car_sales["Odometer (KM)"].plot(kind='hist');

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]', '', regex=True).astype(float).astype(int)

# %%
car_sales["Price"].plot.hist();
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Price"]
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int32

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sale_missing = pd.read_csv("car-sales-missing-data.csv")
car_sale_missing["Colour"].value_counts()
# Out:
# Colour
# White    4
# Blue     2
# Red      1
# Black    1
# Green    1
# Name: count, dtype: int64

# %%
car_sale_missing.isna().sum()
# Out:
# Make        1
# Colour      1
# Odometer    4
# Doors       1
# Price       2
# dtype: int64

# %%
car_sale_missing["Odometer"].fillna(car_sale_missing["Odometer"].mean(), inplace=True)

# %%
car_sale_missing["Odometer"].isna().sum()
# Out:
# 0

# %%
car_sale_missing.dropna(axis=0, inplace=True)

# %%
car_sale_missing.isna().sum()
# Out:
# Make        0
# Colour      0
# Odometer    0
# Doors       0
# Price       0
# dtype: int64

# %%
len(car_sale_missing)
# Out:
# 6

# %%
car_sales["seats"] = 5

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats
# 0  Toyota  White         150043      4   4000      5
# 1   Honda    Red          87899      4   5000      5
# 2  Toyota   Blue          32549      3   7000      5
# 3     BMW  Black          11179      5  22000      5
# 4  Nissan  White         213095      4   3500      5
# 5  Toyota  Green          99213      4   4500      5
# 6   Honda   Blue          45698      4   7500      5
# 7   Honda   Blue          54738      4   7000      5
# 8  Toyota  White          60000      4   6250      5
# 9  Nissan  White          31600      4   9700      5

# %%
import numpy as np
car_sales["Engine-Size"] = np.random.randint((1,6), size=(10,1))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  Engine-Size
# 0  Toyota  White         150043      4   4000      5            0
# 1   Honda    Red          87899      4   5000      5            4
# 2  Toyota   Blue          32549      3   7000      5            0
# 3     BMW  Black          11179      5  22000      5            5
# 4  Nissan  White         213095      4   3500      5            0
# 5  Toyota  Green          99213      4   4500      5            3
# 6   Honda   Blue          45698      4   7500      5            0
# 7   Honda   Blue          54738      4   7000      5            5
# 8  Toyota  White          60000      4   6250      5            0
# 9  Nissan  White          31600      4   9700      5            4

# %%
car_sales["price/Km"]= car_sales["Price"]/car_sales["Odometer (KM)"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  